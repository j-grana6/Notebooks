# %%
from IPython.display import Image
from adsy.ipython import extended_styles
extended_styles()
# Out:
#         <script type="text/javascript">
#         var toggleInput;
#         (function() {
#             var inputInterval;
#             var intervalCount = 0;
#             var init = false;
#             var inputUp = false;
#             toggleInput = function() {
#                 if(inputUp) {
#                     $('div.input').slideDown();
#                     $('div.code_cell').attr('style', '');
#                 }
#                 else {
#                     $('div.input').slideUp();
#                     $('div.code_cell').attr('style', 'padding: 0px; margin: 0px');
#                 }
#                 inputUp = !inputUp;
#                 init = true;
#             }
#             function initExtendedStyles() {
#                 if(intervalCount > 15) {
#                     clearInterval(inputInterval);
#                 }
#                 intervalCount += 1;
#                 try {
#                     toggleInput();
# ...

# %%
# %%javascript
# IPython.load_extensions("calico-spell-check");

# %% [markdown]
# # Progress Report for Project Firestorm

# %% [markdown]
# ### October 8, 2014

# %% [markdown]
# ## Basic Elements

# %% [markdown]
# * Physical Quantities (Fire, Geographical Characteristics, Locations of Agents)
# * Incident Commander
# * UAV Operator (multiple)
# * UAV (multiple)
# * Firefighter (multiple)
# * Fire Simulator and Database
# * Agent Goals (Surveillance, extinguish fire, efficient use of resources)

# %% [markdown]
# ## Graphical Structure

# %%
Image('./sft_presentations/combined_graph.png', width=600)

# %% [markdown]
# * Each node has an internal state.
# * Nodes can send "messages" along their directed edges.
#     * As an example, a message from "Fire" to "Firefighter" can be an observation.
# * Parameters of the Physical System are set a priori.
# * Parameters of the human agents are optimized.
#     * Humans can choose to change their state and send messages.

# %% [markdown]
# ## Optimal Strategies and Monte Carlo Tree Search

# %% [markdown]
# * Monte Carlo Tree Search
#     * Online Dynamic Programming
#     * Has shown to work well in games with large state spaces ($10^{57}$)
#     * Promising potential for adaptation into network structure

# %% [markdown]
# ## What's to come

# %% [markdown]
# * Move beyond current, simple examples
# * Examine the potential of MCTS in real-world, firefighting scenario
# * Incorporate multiple agents
# * Continue working with field experts to drill down details
