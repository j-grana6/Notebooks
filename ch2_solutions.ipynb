# %% [markdown]
# # Chapter 2 Detailed Solutions

# %% [markdown]
# ## Question 13

# %% [markdown]
# Although you can argue for both sides, the more reasonable opinion is to disagree.  A tax on cigarettes will indeed reduce demand (shift down).  Furthermore, it is also reasonable to expect that the price of cigarettes will decrease due to the reduced demand.  However, it is not reasonable to expect that the increase in quantity due to the drop in price will outweigh the drop in quantity due to the tax.  The only way that this would be the case would be if demand were perfectly inelastic (demand curve vertical).

# %%
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %%
import numpy as np
from matplotlib import pyplot as plt
x= np.arange(0,5,.1)
qd = 5-x
qs = x
qdp = 4-x
plt.plot(x, qs, label='Supply')
plt.plot(x, qd, label = 'Demand')
plt.plot(x, qdp, label ='After tax Demand')
plt.legend(loc=4)
plt.text(1.5, 2.6, 'Q loss due to tax')
plt.arrow(2.5, 2.5, -1, 0, head_width=.1, head_length=.1)
plt.arrow(1.4, 2, .5, 0, head_width = .1, head_length=.1)
plt.text(0, 2.1, 'Q gain from price drop')
plt.show()

# %% [markdown]
# ## Question 16

# %% [markdown]
# First, we compute the before tax-reform equilibrium by sequating supply and demand.
#
# $Q_d = 300-4P \;$ and $\; Q_s = 3P-120$
#
# $300-4P = 3P-120$
#
# $420 = 7P$
#
# $P = 60 \;$   therefore   $\; Q_s = 3(60)-120=60 \;$  and  $Q\;_d = 300 - 4(60)= 60 \; $ so the before reform equilibrium is $\;P=60\;$ and $\;Q= 60\;$
#
# With the tax reform, the supply function changes to $ Q_s' = 3.2P-120 \;$.  Now we need to get the after reform equilibrium by setting the after reform supply equal to demand:
#
# $3.2P -120 = 300-4P$
#
# $7.2P =420$
#
# $P = 58 \frac{1}{3}\;$ and $Q = 66\frac{2}{3}.\;$  To see how much each consumer saves (per unit) we find the difference in the two equilibrium prices:
#
# Unit Savings = $60 - 58\frac{1}{3} = 1\frac{2}{3}\;$ or $\$1.66$

# %% [markdown]
# ## Question 18

# %%
x= np.arange(0,5,.1)
qd = 5-x
qs = x
qdp = 4-x
plt.plot(x, qs, label='Supply')
plt.plot(x, qd, label = 'Demand')
plt.ylabel('Price per transaction')
plt.xlabel('Transaction Volume')
plt.plot(x, np.ones(len(x))*1.5)
plt.annotate('(12 Million, $3.00)', xy=(2.5, 2.5), xytext=(3, 4), arrowprops=dict(facecolor='black', shrink=0.05))
plt.text(0, 1.5, 'Ceiling at 1.25')
plt.annotate('5M', xy=(1.5, 1.5), xytext = (1.7, 1.0),arrowprops=dict(facecolor='black', shrink=0.05))
plt.annotate('19M', xy=(3.5, 1.5), xytext = (3.2, 1.0),arrowprops=dict(facecolor='black', shrink=0.05))
plt.text(1.7, .5, 'Shortage of 14 Million')
plt.tick_params(axis= 'both', bottom = 'off', labelbottom='off', labelleft='off')

# %% [markdown]
# Note that the cost to consumers however is more than just the $\$ 1.25$ transaction cost.  Since there are a shortage of 14 million transactions, the consumer will spend an average 14 minutes looking for an ATM.  At a rate of $\$24$ per hour, 14 minutes is worth $24 \cdot \frac{14}{60}=\$5.60$.  Therefore the total cost to consumers is $ \$1.25 + \$5.60 =\$6.85$.

# %% [markdown]
# ## Question 20

# %% [markdown]
# $Q_d^{desktop} = 1600-2P_{desk} +.6M \; $, Income next year = $\$61,300$, Price next year = $\$980$
#
# $Q_d^{memory} = 11,200-100P_{mem} -2P_{desk}$
#
# Number of firms = 100
#
# $Q_s^memory = 1000+25P_{mem}+N$
#
# To tackle this question, we need to sift through a bunc of unnecessary information.  Since we are only concerned with the memory market and the price of desktops is given, we can ignore the demand function for desktops.  To determine market equilibrium we need to set $\; Q_d^{mem}=Q_s^{mem}$.
#
# $11200-100P_{mem}- 2P_{desk} = 1000+25P_{mem}+N\;$ In this case, we know $N$ and $P_{desk}$ so we can just plug in and solve as usual.
#
# $11200-100P - 2(980) = 1000 +25P+100$
#
# $11200 - 1960-1000-100 = 25P+100P$
#
# $8140 = 125P$
#
# $P=65.12\;$ which means $\;Q = 1000+25(65.12)+100 = 2728=Q$
#
# However, since 2728 is market demand, we need to divide by 100 to get the demand facing the firm (remember, we are assuming all firms produce the same number of units).  Therefore, we should tell the CEO to manufacture 27.28 (thousand) units.
#
# If the price of desktops were 1040, we just plug in 1040 where we plugged in 980 and re-solve.
#
#
# $11200-100P - 2(1080) = 1000 +25P+100$
#
# $11200 - 2160-1000-100 = 25P+100P$
#
# $7939 = 125P$
#
# $P=63.52\;$ which means $\;Q = 1000+25(63.52)+100 = 2688=Q$
#
# Similaraly, dividing by 100, Viking should produce 26.88 (thousand) units.
#
# Since when the price of desktops went up, the quantity of memory went down, we can conclude that the goods are compliment.  Note that the negative coefficient of $P_{desk}$ in the demand for memory was enough to conclude that the goods are compliments.

# %% [markdown]
# <script type="text/javascript">
# show=true;
# function toggle(){
# if (show){
# $('div.input').hide();
# }else{
# $('div.input').show();
# }
# show = !show
# }
# </script>
# <a href="javascript:toggle()" target="_self">toggle input</a>
